# %%
#importing the library 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#reading the data from csv file using pandas
dataset=pd.read_csv('Mall_Customers.csv')

# %%
#print the values 
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
#with the values selcted full rows and selective columns
x=dataset.iloc[:,3:5]
x
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# 0                    15                      39
# 1                    15                      81
# 2                    16                       6
# 3                    16                      77
# 4                    17                      40
# ..                  ...                     ...
# 195                 120                      79
# 196                 126                      28
# 197                 126                      74
# 198                 137                      18
# 199                 137                      83
#
# [200 rows x 2 columns]

# %%
#model Creation
from sklearn.cluster import SpectralClustering
from sklearn.datasets import make_blobs
# Generate sample data
blobs = make_blobs(n_samples=300, centers=4, random_state=42)
#Apply the Spectral Clustering
clustermodel=SpectralClustering(n_clusters=8 ,random_state=None, n_neighbors=50, n_jobs=50)
label=clustermodel.fit_predict(x)
# Out:
# C:\Anconda\lib\site-packages\sklearn\cluster\_kmeans.py:366: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   est = KMeans(

# %%
#assigning the values dataset to supervised 
supervised=dataset

# %%
#to print the values of supervised
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
#append the clustered values on supervised table 
supervised['cluster_group']=label

# %%
#view the appended values on table
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      cluster_group
# 0                7
# 1                7
# 2                7
# 3                7
# 4                7
# ..             ...
# 195              7
# 196              3
# 197              7
# 198              1
# 199              2
#
# [200 rows x 6 columns]

# %%
#to save the table of content to csv file
supervised.to_csv("cluster",index=False)

# %%
#to plot the cluster in graph, in this hue use for difference of cluster,
#fit_reg for plot the coorect manner
import seaborn as sns
facet=sns.lmplot(data=supervised,x=supervised.columns[3],y=supervised.columns[4],
                 fit_reg=False,hue=supervised.columns[5],legend=True,legend_out=True)
plt.title('Spectral Clustering Result')
plt.show()
# Out:
# C:\Anconda\lib\site-packages\seaborn\regression.py:592: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
